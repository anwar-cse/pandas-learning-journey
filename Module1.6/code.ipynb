# %% [markdown]
# GroupBy

# %%
import pandas as pd

data={
    "name":["anwar","shuvo","rakib","habib"],
    "city":["dhaka","kishoreganj","dhaka","gachihata"],
    "salary":[1000,2000,3000,2000]
}

df=pd.DataFrame(data)
print(df.groupby("city")["salary"].sum())
# Out:
# city
# dhaka          4000
# gachihata      2000
# kishoreganj    2000
# Name: salary, dtype: int64
