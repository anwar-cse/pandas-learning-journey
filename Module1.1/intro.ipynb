# %% [markdown]
# 1.Series

# %%
import pandas as pd

data=[79,26,90,100]
s=pd.Series(data)
print(s)
# Out:
# 0     79
# 1     26
# 2     90
# 3    100
# dtype: int64

# %% [markdown]
# DataFrame

# %%
data={
    "name":["Anwar","Amjat","Dilwar"],
    "age":[25,26,27]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      name  age
# 0   Anwar   25
# 1   Amjat   26
# 2  Dilwar   27

# %% [markdown]
# practice part

# %%
import pandas as pd
lst=[1,3,4,5,6]
print(pd.Series(lst))

print(pd.Series(lst,index=['a','b','c','d','e']))

data={
    "alph":['a','b','c'],
    "ascii_value":[97,98,99]
}
df=pd.DataFrame(data)
print(df)
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64
# a    1
# b    3
# c    4
# d    5
# e    6
# dtype: int64
#   alph  ascii_value
# 0    a           97
# 1    b           98
# 2    c           99
