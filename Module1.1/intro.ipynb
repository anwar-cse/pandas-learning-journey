# %% [markdown]
# 1.Series

# %%
import pandas as pd

data=[79,26,90,100]
s=pd.Series(data)
print(s)
# Out:
# 0     79
# 1     26
# 2     90
# 3    100
# dtype: int64

# %% [markdown]
# DataFrame

# %%
data={
    "name":["Anwar","Amjat","Dilwar"],
    "age":[25,26,27]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      name  age
# 0   Anwar   25
# 1   Amjat   26
# 2  Dilwar   27
