# %% [markdown]
# csv file read

# %%
import pandas as pd

df=pd.read_csv("data.csv")
print(df.head())
# Out:
#     Name  Age        City  Marks
# 0  Anwar   22       Dhaka     85
# 1   Himo   21      Sylhet     78
# 2  Rahim   23  Chittagong     90
# 3  Karim   22      Khulna     88
# 4   Nila   20       Dhaka     92

# %% [markdown]
# read excel file

# %%
df1=pd.read_cxcel("data.xlsx")
print(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1=pd.read_cxcel("data.xlsx")
#       2 print(df1)
#
# AttributeError: module 'pandas' has no attribute 'read_cxcel'

# %% [markdown]
# csv file write (means file save)

# %%
df.to_csv("data1.csv", index=False)
